# %% [markdown]
# This notebook shows how to use Smoothie.
#
# What you will need for a given task:
# * The list of sample inputs (`test_inputs`). In this tutorial, we load this from a jsonl file in `smoothie_data`.
# * A set of models to route among, namely their generations for `test_inputs`. In this tutorial, we have previously saved different model generations in separate jsonl files, and we load and concatenate them to form a numpy array `test_generations` (of size `n_samples` x `n_models`).
#
#
# We will walk through an example on CNN dailymail. To follow along, make sure you download `smoothie_data` from Huggingface, `cd` into the directory, and do `git lfs pull`.
#
# If interested in the mathematical details of the Smoothie algorithm, please see `algorithm.ipynb`.

# %%
import jsonlines
import json 
import numpy as np
from sentence_transformers import SentenceTransformer
from fastembed import TextEmbedding
from sklearn.neighbors import NearestNeighbors

import sys 
sys.path.append("..")
from src.model import Smoothie

# %%
# load test_inputs for the task 
with jsonlines.open("../smoothie_data/datasets/cnn_dailymail_test.jsonl") as file: 
    test_dataset = list(file.iter())
test_inputs = [sample['embedding_input'] for sample in test_dataset] # get the raw inputs for the task (no formatting)

n_samples = len(test_inputs)

# %%
# load test_generations, numpy array (n_samples x n_models) of generations

models = ["mistral-7b", "llama-2-7b", "vicuna-7b", "gemma-7b", "nous-capybara"]
n_models = len(models)
test_generations = []
for model in models:
    predictions_path = f"../smoothie_data/multi_model_results/cnn_dailymail/7b/{model}_test.json"
    with open(predictions_path, "r") as f:
        test_generations.append(json.load(f)['generations'])

test_generations = np.array(test_generations).T

# %%
# embed test_inputs for sample-dependent routing 
# this is used for Smoothie-dependent, in KNN to determine which samples should be used to learn the Smoothie weights for a given test sample 

model_name = "all-mpnet-base-v2"
model = SentenceTransformer(model_name)

test_input_embeddings = model.encode(test_inputs)
# Out:
# /nlp/scr/mfchen/miniconda3/envs/mayeeenv/lib/python3.8/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /nlp/scr/mfchen/miniconda3/envs/mayeeenv/lib/python3.8/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
# embed test_generations --- these are the embeddings used in the main Smoothie algorithm
def clean_generation(generation: str):
    """
    Extracts a generation from the full output of the model.
    """
    generation = generation.replace("<pad>", "")
    generation = generation.replace("<s>", "")
    generation = generation.replace("</s>", "")
    generation = generation.replace("</eos>", "")
    generation = generation.replace("\\n", "\n")
    return generation.strip().split("\n")[0]

cleaned_test_generations = np.array([clean_generation(gen) for gens_per_sample in test_generations for gen in gens_per_sample])

embedding_model = TextEmbedding(
    model_name="BAAI/bge-small-en-v1.5", providers=["CUDAExecutionProvider"]
)
smoothie_embeddings = np.array(list(embedding_model.embed(cleaned_test_generations))).reshape(n_samples, n_models, -1)
embed_dim = smoothie_embeddings.shape[2]
# Out:
# Fetching 5 files:   0%|          | 0/5 [00:00<?, ?it/s]
# 2024-07-02 22:21:51.342983632 [E:onnxruntime:Default, env.cc:228 ThreadMain] pthread_setaffinity_np failed for thread: 54550, index: 1, mask: {1, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-07-02 22:21:51.342997322 [E:onnxruntime:Default, env.cc:228 ThreadMain] pthread_setaffinity_np failed for thread: 54551, index: 2, mask: {49, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-07-02 22:21:51.342983652 [E:onnxruntime:Default, env.cc:228 ThreadMain] pthread_setaffinity_np failed for thread: 54549, index: 0, mask: {48, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-07-02 22:21:51.343012661 [E:onnxruntime:Default, env.cc:228 ThreadMain] pthread_setaffinity_np failed for thread: 54552, index: 3, mask: {2, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-07-02 22:21:51.343048271 [E:onnxruntime:Default, env.cc:228 ThreadMain] pthread_setaffinity_np failed for thread: 54553, index: 4, mask: {50, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-07-02 22:21:51.343133430 [E:onnxruntime:Default, env.cc:228 ThreadMain] pthread_setaffinity_np failed for thread: 54556, index: 7, mask: {4, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-07-02 22:21:51.344186746 [E:onnxruntime:Default, env.cc:228 ThreadMain] pthread_setaffinity_np failed for thread: 54554, index: 5, mask: {3, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-07-02 22:21:51.344257295 [E:onnxruntime:Default, env.cc:228 ThreadMain] pthread_setaffinity_np failed for thread: 54555, index: 6, mask: {51, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-07-02 22:21:51.344263535 [E:onnxruntime:Default, env.cc:228 ThreadMain] pthread_setaffinity_np failed for thread: 54577, index: 28, mask: {62, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-07-02 22:21:51.345767886 [E:onnxruntime:Default, env.cc:228 ThreadMain] pthread_setaffinity_np failed for thread: 54558, index: 9, mask: {5, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-07-02 22:21:51.346801542 [E:onnxruntime:Default, env.cc:228 ThreadMain] pthread_setaffinity_np failed for thread: 54571, index: 22, mask: {59, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-07-02 22:21:51.349759643 [E:onnxruntime:Default, env.cc:228 ThreadMain] pthread_setaffinity_np failed for thread: 54562, index: 13, mask: {7, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-07-02 22:21:51
}, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-07-02 22:21:51.429188013 [E:onnxruntime:Default, env.cc:228 ThreadMain] pthread_setaffinity_np failed for thread: 54634, index: 85, mask: {43, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-07-02 22:21:51.429238503 [E:onnxruntime:Default, env.cc:228 ThreadMain] pthread_setaffinity_np failed for thread: 54631, index: 82, mask: {89, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-07-02 22:21:51.429780256 [E:onnxruntime:Default, env.cc:228 ThreadMain] pthread_setaffinity_np failed for thread: 54638, index: 89, mask: {45, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-07-02 22:21:51.430638605 [E:onnxruntime:Default, env.cc:228 ThreadMain] pthread_setaffinity_np failed for thread: 54639, index: 90, mask: {93, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.

# %%
# Code for smoothie-dependent
# produces smoothie_dataset_weights, an n_samples x n_models numpy array of scores for each generation in test_generations
# for smoothie-dependent, each row of weights is different 

# adjust n_neighbors as you wish
nbrs = NearestNeighbors(n_neighbors=20, algorithm="auto")
nbrs.fit(test_input_embeddings)
_, test_indices = nbrs.kneighbors(test_input_embeddings)

smoothie_dataset_weights = []
for sample_idx in range(n_samples):
    embs_per_sample = smoothie_embeddings[test_indices[sample_idx]]
    smoothie = Smoothie(n_voters=n_models, dim=embed_dim)
    smoothie.fit(embs_per_sample)
    smoothie_dataset_weights.append(smoothie.theta)

smoothie_dataset_weights = np.array(smoothie_dataset_weights)

# %%
# Code for smoothie-independent
# each row of weights in smoothie_dataset_weights is the same - we just use one model for the dataset.
smoothie = Smoothie(n_voters=n_models, dim=embed_dim)
smoothie.fit(smoothie_embeddings)
smoothie_dataset_weights = np.tile(smoothie.theta, (n_samples, 1))

# %%
# finally, select samples according to smoothie weights

routed_texts = []
routed_models = []

for sample_idx in range(n_samples):
    max_idx = smoothie_dataset_weights[sample_idx].argmax()
    text = test_generations[sample_idx][max_idx]
    routed_texts.append(text)
    routed_models.append(models[max_idx])

# %%
routed_texts
# Out:
# ['Justin Rose, a top-five ranked golfer for the past three years, has been struggling with his form recently. He has spent the past two weeks practicing and it seems to have paid off as he had a good round at the Shell Houston Open. He is confident that he is improving and is looking forward to the Masters, where he has had success in',
#  'Lewis Ferguson, an 18-year-old jockey, survived a spectacular fall from Merrion Square at Wincanton on Wednesday. The fall has been watched by hundreds of thousands of people online and Ferguson was mucking out the stables as usual on Thursday morning. He said he was',
#  'The East of England ambulance service has revealed some of the most bizarre and irritating call outs they have received in the last two years. These include a call about a squirrel that had been run over, a man reporting that his burger was bleeding, and a woman who had eaten too much takeaway food. The service receives around 2,5',
#  "A couple in China who were unable to get married due to the girlfriend's hospitalization had their wedding photographs taken for her birthday. The girlfriend, Dong Hui, was diagnosed with bone cancer and had to be admitted to hospital, but her boyfriend, Guo Kai, arranged for professional photographers to come to the hospital",
#  'Corinthian Colleges Inc. has announced that it will shut down all of its remaining 28 campuses, which enrolled over 70,000 students. Corinthian is one of the worst "predator colleges" that offer dubious degrees, saddle students with high amounts of debt, and gobble up tens of bill',
#  'The Boston Marathon is an annual event that brings people together in celebration. However, in 2013 it was marred by a terrorist attack that resulted in the death of three people and injuries to over 200. The perpetrator of these attacks, Dzhokhar Tsarnaev, was convicted on all 30 counts he faced after',
#  'Nick Clegg vowed to cling on as Liberal Democrat leader even if the party is wiped out at the polls. He also said he wants to lead the Liberal Democrats into and through the next Parliament in all circumstances.</s>',
#  'The article discusses the ongoing competition among tech companies to improve the battery life of their devices, including smartphones, tablets, and electric cars. Google is reportedly working on developing new battery technologies, and Apple is also recruiting experts to enhance battery performance across its product line. The article mentions various innovative battery technologies being developed, such as aluminum batteries, low',
#  'A woman was left scarred for life after being knocked down by a cyclist who was riding on the pavement. The cyclist fled the scene, and the victim suffered two three-inch gashes to the middle of her forehead, as well as other facial and hand injuries. The police have issued CCTV footage of a cycl',
#  "Suge Knight, the co-founder of Death Row Records, is currently on trial for murder and attempted murder. Despite being refused an appeal to reduce his bail from $10 million to $5 million, Knight remains confident that his friend and fellow boxer, Floyd Mayweather, will bail him out after Mayweather's next fight.",
#  'A gun trafficker for Aaron Hernandez, the former New England Patriots player who was recently sentenced to life in prison, said he was "awed" by Hernandez and "grateful to be noticed" when Hernandez paid him $15,000 for three guns a month before the murder of Odin Lloyd. The',
#  'The chair in which Abraham Lincoln was shot in 1865 will be displayed at the Henry Ford Museum in Dearborn, Michigan, on April 15 to commemorate the 150th anniversary of the assassination. The chair has been at the museum for 85 years and has a dark stain on the back that many visitors',
#  'Tottenham is considering a new £400million stadium design that includes a retractable pitch for the NFL. The stadium, due to be completed for the 2018-19 season, could have an NFL-style synthetic surface housed underneath the grass pitch. The NFL is said to be within five years of having a permanent franchise in',
#  "A pensioner in Somerset, England was attacked by a large badger with six-inch teeth while sitting in his garden with his dog. The badger burst through a hedge with two cubs and the pensioner's dog saved him by pulling him back indoors. The National Farmers' Union has issued advice on protecting property from inv",
#  "The article discusses the transformation of Kabul, Afghanistan after NATO's withdrawal. The city has grown in size but has become smaller in scope. The article highlights the plight of five English-speaking men who were fired from their jobs and blacklisted by the government and NGOs. They are now living in market stalls and avoid",
#  'A chef created a massive burger called "The Whole Damn Farm" that contains six types of meat from three different animals and costs £13.50. It has two beef patties, a fried chicken thigh, pulled pork, ham chunks, and bacon. It\'s a challenge for people to eat it.</s>',
#  'Hillary Clinton\'s campaign team met in Brooklyn on Saturday to discuss the campaign\'s values, goals, and strategies for winning the presidency. The team, led by campaign manager Robby Mook, distributed a "values statement" that emphasized humility, discipline, and unity, and outlined the campaign\'s purpose to give every family and small business a path to',
#  'Chile has enacted a new law that recognizes civil unions between people of the same sex, joining several of its South American neighbors in allowing the unions. The law is intended to end discrimination faced by common-law couples and gives the couples greater rights in the realms of property, health care, pensions, and inheritance. The',
#  "Jack Wilshere made his long-awaited return from injury in Arsenal U21's 1-0 defeat by Reading. Former Arsenal defender Martin Keown's son Niall scored the winner for the visitors after just eight minutes. Wilshere and other injured first team players, including Abou Diaby and Serge Gnabry, featured",
#  "Rhiannon Taylor, a 29-year-old travel photographer from Australia, has turned her love for traveling and photography into a business by launching a website called 'In Bed With'. She travels the world to review and photograph the most luxurious accommodations, and has gained a large following on Instagram with over 12,000 followers. Rh",
#  'A new device called Roboscan 2M Aeria has been created by a Romanian company, MB Telecom. It is an airplane scanner that can detect contraband, bombs and weapons inside planes. The scanner uses a cone of radiation to sweep across planes and look inside. It is accurate enough to find a filament in a light bulb',
#  'Bayern Munich will be without their versatile left-back David Alaba for around seven weeks due to a torn knee ligament he suffered while playing for Austria. Alaba had been in excellent form for Bayern this season, helping them stay on track for a treble of titles with some spectacular goals. He is set to start rehabilitation work in',
#  "Hundreds of thousands of Brazilians are protesting in the streets against President Dilma Rousseff, who is struggling with an economic downturn and a massive bribery scandal at the state-run oil company Petrobras. The protesters are calling for Rousseff's impeachment, while her suppor",
#  "A Florida man named Justin Jackson has been accused of posing as Oprah Winfrey, executives from her TV network, former Obama aide Reggie Love, and Madonna's manager in order to obtain jobs, free food, jewelry, and other items worth over $2.4 million. Jackson has been carrying out these schemes for eight years, starting with",
#  "Liam Plunkett is ready to make a name for himself in the West Indies by using his pace to 'rough up' the batting line-up. He is back in Test contention after his comeback was cut short by injury and wants to use his pace to lead England to victory in the Test series against West Indies. Plunkett has",
#  "\nCadbury has reduced the size of its Freddo Frog chocolates by 20%, from 15g to 12g, but has kept the recommended retail price the same. The change was not widely announced and was first noticed by a shop owner. Cadbury's spokesman attributed the size reduction to manufacturing cost increases. This is",
#  'Gizzi Erskine, a stylish cook and cat lover, posed with her pet cat Kimchi for a photo shoot in a magazine called Puss Puss. Kimchi has a discerning palate and loves human food, such as poppadoms and tortilla chips. The chef also has a new addition to her cat family',
#  'A group of U.S. senators wrote to FIFA, calling for Russia to be removed as host of the 2018 World Cup due to its role in the Ukraine crisis and occupation of Crimea. They said allowing Russia to host the tournament would inappropriately bolster the prestige of the Putin regime and provide economic relief while the international community im',
#  'A Spanish town on the Camino de Santiago pilgrimage route is warning visitors not to defecate along the famous path. Graphic signs have been erected in the municipality of Lastres, showing a squatting figure defecating within a red circle with a diagonal line across it. The signs are posted next to warnings that urge people not to litter.',
#  'Derry Mathews won the interim WBA lightweight title after defeating Tony Luis in a unanimous points decision in Liverpool. Mathews had to overcome several obstacles to get to the fight, including two opponents pulling out due to illness and a replacement failing to obtain a visa. The fight was a close and exciting contest, with',
#  'The article discusses the decision of planners in Windsor to allow two Costa cafes less than 500 yards apart. The latest Costa will open on the site of the former Dedworth Road HSBC branch, while the other Costa replaced a cycle shop earlier this year. A resident expressed concern about the number of fast food and coffee sh',
#  'A photo of Jose Mourinho and Pep Guardiola in deep conversation during a Barcelona training session went viral a few years ago, with many people guessing what they might have been saying. The image was taken during the 1996-97 season, when both men were at Barcelona. Since then, several other coaches have emerged from that team',
#  'A young mother and her three children were found murdered in their home in Tisdale, Saskatchewan. The suspect in the case was found dead hours later, but it was not a homicide. The family of the victims has started a GoFundMe page to raise money for the funeral services.</s>',
#  "A zookeeper in Tel Aviv placed a GoPro camera at the bottom of water troughs to capture animals drinking in their own unique way. The animals, ranging from a rhino to a lemur, were recorded for 30 hours and the footage was cut down to four minutes. The animals' drinking habits differed, with car",
#  '\nBecca and Dale Litchfield, a couple from Nottingham, faced a difficult decision when they realized they could only afford either a wedding or one last attempt at IVF to have a family. Heartbroken, they chose to forgo their dream wedding and went ahead with IVF treatment. Their gamble paid off when Becca became pregnant with twins',
#  'Mark Ronson\'s "Uptown Funk!" featuring Bruno Mars has spent 13 weeks at No. 1 on the Billboard Hot 100 chart, making it the longest-leading single of the 2010s. The song has also become one of the 10 singles to spend at least 13 weeks at No',
#  "Scientists have created a complete 3D map of Mars for the first time by joining individual strips of imagery that were previously too skinny to create a complete map. The new map covers 1.4 million square miles of the red planet's surface and allows scientists to better understand how water and lava once flowed across the planet. The map",
#  '\nThe Medicines and Healthcare Products Regulatory Agency (MHRA) in the UK has approved a traditional Chinese herbal remedy called Phynova Joint and Muscle Relief, which contains sigesbeckia, a herb traditionally used to treat aches and pains caused by arthritis. Professor George Lewith, a complement',
#  'A Baltimore mother, Toya Graham, was interviewed by CNN about her actions of slapping and pulling her son out of a protest. She stated that she was not concerned about embarrassing her son and that she was there to protect him. The video of her actions has been praised by many as #motheroftheyear. The mother explained that she',
#  "An 11-year-old boy with autism drew an accurate world map from memory during his mother's professor's class. The detailed drawing included political borders and small islands.</s>",
#  'Cameron Hooker, who kept a hitchhiker as sex slave for seven years, was handed a 104-year sentence in 1985. He was denied parole in a recent hearing.</s>',
#  'The article discusses the exorbitant prices of tickets for the upcoming boxing match between Floyd Mayweather and Manny Pacquiao. It states that secondary sites have tickets available at crazy money, with ringside seats going for $180,000. It also mentions that the most expensive seat on sale through StubHub was retail',
#  '\nRepublican presidential candidate Rand Paul is under fire for his behavior towards female journalists, particularly his exchange with TODAY host Savannah Guthrie. Paul has denied having a problem with women and admitted to being short-tempered with both male and female reporters. He also had a confrontation with Democratic National Committee Chair Debbie Wasserman Schultz',
#  "A judge in Atlanta reduced the prison sentences of three educators involved in a cheating scandal in the Atlanta Public Schools from seven years to three years. The judge also ordered community service and fines. The educators were convicted of racketeering for allegedly altering test answers to boost the schools' scores. The judge had come under criticism for giving harsh sentences to the",
#  "Posters promoting a 'straight pride' week at Youngstown State University were removed after student leaders determined that the message went beyond free speech. The posters contained profanity and encouraged students to celebrate by not highlighting their sexual orientation. Student leaders said that while they believe the posters were meant as satire, the message was inappropri",
#  'China has announced that it will start tracking the behavior of its citizens abroad in order to prevent any further incidents of bad behavior by Chinese tourists. The China National Tourism Administration (CNTA) said that provincial and national authorities will be in touch with unruly citizens when they return to China, and if necessary, the police, customs officers, border control,',
#  'Tom Daley, a former world champion, is hoping to win Olympic gold at the 2016 Rio de Janiero Games with a new dive he calls the "firework." He spent the winter modifying the dive with new coach Jane Figueiredo and it was premiered at the British Championships, where Daley won silver with a personal',
#  "A man has been charged with killing his wife at a Dunkin' Donuts store in Maryland where they both worked. The victim, 21-year-old Palak Bhadreskumar Patel, was found severely injured in the kitchen area and died at the scene. The suspect, 24-year-old Bhadreshkumar",
#  'African soccer leaders have pledged their support for Sepp Blatter in the upcoming FIFA presidential election. Issa Hayatou, president of the Confederation of African Football, promised unanimous backing for Blatter during the CAF annual congress in Cairo. Blatter, who is seeking a fifth term in office, received praise from Hayatou and other African',
#  'Coca-Cola has caused confusion among its fans by switching the lids on Diet Coke bottles from white to red, making them look identical to regular Coke bottles. The change has left some consumers baffled and disappointed, as Diet Coke used to have a distinct white lid. Coca-Cola claims the change is part of an effort to bring',
#  "The article discusses the criticism directed towards Manchester City's midfielder, Yaya Toure, by various pundits and experts following the team's 4-2 derby loss to Manchester United. The article highlights the defensive lapses and lack of effort from Toure, which have been a recurring issue in his game. The",
#  "England won the Sevens World Series title in Tokyo after beating South Africa 21-14 in the final. This victory was England's first since February 2013 and put them in fourth place in the series, ahead of Australia. South Africa still leads the way with 129 points, four clear of Fiji. The Fijians",
#  'A Ukrainian Premier League club, FC Chernomorets Odessa, is offering their players houses by the sea in exchange for wages due to their severe financial plight. The club is struggling to pay their players and is at risk of relegation and disqualification from UEFA competitions. The houses are valued at around £67,00',
#  'A drug dealer in Tulsa County, Oklahoma, decided to transport $30,000 worth of meth by stuffing it into an Easter bunny and mailing it. The package was intercepted by police and the intended recipient, Carolyn Ross, was arrested. The police found two condoms filled with meth inside the bun',
#  "Researchers have found that rats can recognize pain in the faces of other rats, suggesting that the rodents' facial expressions may have a communicative function. The study involved showing rats photographs of other rats with either neutral or pained expressions, and observing how long they spent in different rooms. The rats spent less time in the room with",
#  'A community center and apartment complex in East Baltimore, Maryland, burned down after the funeral of Freddie Gray, who died in police custody. The center was to provide services such as behavioral health counseling, support for people with HIV/AIDS, and employment training. The cause of the fire is still under investigation, but local',
#  'Ciudad Real airport in Spain was built in 2009 at a cost of €1 billion and was intended to serve both Madrid and the Andaluscian coast. However, it closed three years later when its parent company fell into financial difficulties. The airport is now being sold off for just €100 million, with no takers and no minimum asking',
#  "Aston Villa's Jack Grealish, who was a fan at Wembley when Villa lost to Manchester United and Chelsea in 2010, is hoping to make a difference as a player when Villa face Liverpool in the FA Cup semi-final. Grealish made his first Premier League start against QPR and is hopeful of retaining his",
#  '\nA former bomb disposal expert has won his battle with the bulge after shedding half his bodyweight after undergoing gastric bypass surgery. Steve Tempest-Mitchell, from Bradford, West Yorkshire, lost a whopping 16st after the surgery 14 months ago, which caused his stomach to shrink to the size of a tennis ball. The 56-year-old said',
#  '\nThe article reports that after an unusually warm April, the UK is expected to experience a significant drop in temperatures, with the arrival of an Arctic airmass. This change will result in temperatures that are colder than those in Moscow, Stockholm, and Finland, and could make for a wet and miserable London Marathon. The Met Office predicts rain and potential thunder']

# %%
routed_models
# Out:
# ['vicuna-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'nous-capybara',
#  'vicuna-7b',
#  'mistral-7b',
#  'nous-capybara',
#  'nous-capybara',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'mistral-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'nous-capybara',
#  'nous-capybara',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'mistral-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'mistral-7b',
#  'nous-capybara',
#  'nous-capybara',
#  'vicuna-7b',
#  'nous-capybara',
#  'nous-capybara',
#  'nous-capybara',
#  'nous-capybara',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'llama-2-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'mistral-7b',
#  'nous-capybara',
#  'mistral-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'nous-capybara',
#  'nous-capybara',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'mistral-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'nous-capybara',
#  'mistral-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'mistral-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'nous-capybara',
#  'nous-capybara',
#  'nous-capybara',
#  'vicuna-7b',
#  'mistral-7b',
#  'mistral-7b',
#  'mistral-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'mistral-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'gemma-7b',
#  'mistral-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'gemma-7b',
#  'gemma-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'mistral-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'gemma-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'mistral-7b',
#  'mistral-7b',
#  'mistral-7b',
#  'gemma-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'nous-capybara',
#  'mistral-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'mistral-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'mistral-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'nous-capybara',
#  'nous-capybara',
#  'mistral-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'nous-capybara',
#  'nous-capybara',
#  'vicuna-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'nous-capybara',
#  'nous-capybara',
#  'nous-capybara',
#  'vicuna-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'nous-capybara',
#  'mistral-7b',
#  'nous-capybara',
#  'mistral-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'gemma-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'mistral-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'nous-capybara',
#  'mistral-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'mistral-7b',
#  'nous-capybara',
#  'nous-capybara',
#  'mistral-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'nous-capybara',
#  'nous-capybara',
#  'gemma-7b',
#  'nous-capybara',
#  'mistral-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'nous-capybara',
#  'mistral-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'nous-capybara',
#  'nous-capybara',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'mistral-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'nous-capybara',
#  'gemma-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'gemma-7b',
#  'mistral-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'mistral-7b',
#  'nous-capybara',
#  'gemma-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'nous-capybara',
#  'vicuna-7b',
#  'nous-capybara',
#  'mistral-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'mistral-7b',
#  'gemma-7b',
#  'mistral-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'nous-capybara',
#  'nous-capybara',
#  'vicuna-7b',
#  'mistral-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'nous-capybara',
#  'nous-capybara',
#  'mistral-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'mistral-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'mistral-7b',
#  'nous-capybara',
#  'mistral-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'gemma-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'mistral-7b',
#  'gemma-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'mistral-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'nous-capybara',
#  'nous-capybara',
#  'vicuna-7b',
#  'mistral-7b',
#  'nous-capybara',
#  'nous-capybara',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'mistral-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'nous-capybara',
#  'nous-capybara',
#  'nous-capybara',
#  'vicuna-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'mistral-7b',
#  'mistral-7b',
#  'gemma-7b',
#  'nous-capybara',
#  'gemma-7b',
#  'nous-capybara',
#  'mistral-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'nous-capybara',
#  'vicuna-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'gemma-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'nous-capybara',
#  'vicuna-7b',
#  'mistral-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'nous-capybara',
#  'mistral-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'nous-capybara',
#  'mistral-7b',
#  'nous-capybara',
#  'mistral-7b',
#  'nous-capybara',
#  'nous-capybara',
#  'vicuna-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'mistral-7b',
#  'mistral-7b',
#  'mistral-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'gemma-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'gemma-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'nous-capybara',
#  'nous-capybara',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'gemma-7b',
#  'mistral-7b',
#  'mistral-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'mistral-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'mistral-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'llama-2-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'nous-capybara',
#  'mistral-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'gemma-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'mistral-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'mistral-7b',
#  'nous-capybara',
#  'nous-capybara',
#  'nous-capybara',
#  'nous-capybara',
#  'vicuna-7b',
#  'nous-capybara',
#  'nous-capybara',
#  'mistral-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'nous-capybara',
#  'mistral-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'mistral-7b',
#  'nous-capybara',
#  'nous-capybara',
#  'vicuna-7b',
#  'mistral-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'nous-capybara',
#  'mistral-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'mistral-7b',
#  'mistral-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'nous-capybara',
#  'mistral-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'mistral-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'nous-capybara',
#  'mistral-7b',
#  'mistral-7b',
#  'mistral-7b',
#  'nous-capybara',
#  'nous-capybara',
#  'vicuna-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'mistral-7b',
#  'nous-capybara',
#  'nous-capybara',
#  'nous-capybara',
#  'vicuna-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'gemma-7b',
#  'mistral-7b',
#  'mistral-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'nous-capybara',
#  'nous-capybara',
#  'vicuna-7b',
#  'gemma-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'nous-capybara',
#  'nous-capybara',
#  'vicuna-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'mistral-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'mistral-7b',
#  'nous-capybara',
#  'mistral-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'mistral-7b',
#  'mistral-7b',
#  'mistral-7b',
#  'mistral-7b',
#  'mistral-7b',
#  'nous-capybara',
#  'mistral-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'nous-capybara',
#  'mistral-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'mistral-7b',
#  'mistral-7b',
#  'nous-capybara',
#  'mistral-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'gemma-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'nous-capybara',
#  'mistral-7b',
#  'nous-capybara',
#  'mistral-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'nous-capybara',
#  'nous-capybara',
#  'nous-capybara',
#  'nous-capybara',
#  'vicuna-7b',
#  'mistral-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'mistral-7b',
#  'nous-capybara',
#  'gemma-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'mistral-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'mistral-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'mistral-7b',
#  'mistral-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'mistral-7b',
#  'mistral-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'mistral-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'mistral-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'nous-capybara',
#  'vicuna-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'nous-capybara',
#  'nous-capybara',
#  'mistral-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'mistral-7b',
#  'nous-capybara',
#  'nous-capybara',
#  'vicuna-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'gemma-7b',
#  'nous-capybara',
#  'nous-capybara',
#  'vicuna-7b',
#  'nous-capybara',
#  'mistral-7b',
#  'gemma-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'nous-capybara',
#  'vicuna-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'nous-capybara',
#  'vicuna-7b',
#  'vicuna-7b',
#  'gemma-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'mistral-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'nous-capybara',
#  'mistral-7b',
#  'mistral-7b',
#  'nous-capybara',
#  'mistral-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'mistral-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'gemma-7b',
#  'nous-capybara',
#  'mistral-7b',
#  'mistral-7b',
#  'nous-capybara',
#  'mistral-7b',
#  'nous-capybara',
#  'mistral-7b',
#  'mistral-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'gemma-7b',
#  'mistral-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'gemma-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'nous-capybara',
#  'mistral-7b',
#  'nous-capybara',
#  'mistral-7b',
#  'nous-capybara',
#  'nous-capybara',
#  'vicuna-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'nous-capybara',
#  'nous-capybara',
#  'nous-capybara',
#  'vicuna-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'vicuna-7b',
#  'nous-capybara',
#  'nous-capybara',
#  'nous-capybara',
#  'mistral-7b',
#  'nous-capybara',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'mistral-7b',
#  'nous-capybara',
#  'nous-capybara',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'vicuna-7b',
#  'mistral-7b',
#  'gemma-7b',
#  'mistral-7b']
